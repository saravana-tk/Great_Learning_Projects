# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
#Import tensorflow
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
#Import the dataset
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Clear any existing model in memory
tf.keras.backend.clear_session()

#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Reshape data from 2D (28,28) to 3D (28, 28, 1)
model.add(tf.keras.layers.Reshape((28,28,1),input_shape=(28,28,)))

#Flatten the output
model.add(tf.keras.layers.Flatten())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#First dense layer
model.add(tf.keras.layers.Dense(200, activation='relu'))

#Second dense layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

#Add first dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
#Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=25)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 4s 63us/sample - loss: 16.8074 - accuracy: 0.7451 - val_loss: 23.9098 - val_accuracy: 0.7342
# Epoch 2/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 12.2810 - accuracy: 0.7867 - val_loss: 12.6808 - val_accuracy: 0.7784
# Epoch 3/25
# 60000/60000 [==============================] - 3s 55us/sample - loss: 11.3484 - accuracy: 0.7963 - val_loss: 12.4380 - val_accuracy: 0.7951
# Epoch 4/25
# 60000/60000 [==============================] - 3s 53us/sample - loss: 11.3159 - accuracy: 0.7986 - val_loss: 23.9268 - val_accuracy: 0.7236
# Epoch 5/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.5930 - accuracy: 0.8027 - val_loss: 11.5142 - val_accuracy: 0.8011
# Epoch 6/25
# 60000/60000 [==============================] - 3s 55us/sample - loss: 10.9312 - accuracy: 0.8020 - val_loss: 12.4425 - val_accuracy: 0.7671
# Epoch 7/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.5365 - accuracy: 0.8048 - val_loss: 18.4970 - val_accuracy: 0.7337
# Epoch 8/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.3255 - accuracy: 0.8069 - val_loss: 12.3267 - val_accuracy: 0.7663
# Epoch 9/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.0657 - accuracy: 0.8089 - val_loss: 11.0893 - val_accuracy: 0.8001
# Epoch 10/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.1808 - accuracy: 0.8084 - val_loss: 12.1239 - val_accuracy: 0.8012
# Epoch 11/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.5656 - accuracy: 0.8105 - val_loss: 13.4060 - val_accuracy: 0.7664
# Epoch 12/25
# 60000/60000 [==============================] - 3s 55us/sample - loss: 9.9836 - accuracy: 0.8090 - val_loss: 15.0191 - val_accuracy: 0.7739
# Epoch 13/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 10.1092 - accuracy: 0.8077 - val_loss: 12.4283 - val_accuracy: 0.7920
# Epoch 14/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.8590 - accuracy: 0.8108 - val_loss: 15.6393 - val_accuracy: 0.7309
# Epoch 15/25
# 60000/60000 [==============================] - 3s 55us/sample - loss: 9.7737 - accuracy: 0.8114 - val_loss: 11.9513 - val_accuracy: 0.7931
# Epoch 16/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.6625 - accuracy: 0.8112 - val_loss: 12.9761 - val_accuracy: 0.7935
# Epoch 17/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.9177 - accuracy: 0.8099 - val_loss: 14.6340 - val_accuracy: 0.7722
# Epoch 18/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.7755 - accuracy: 0.8104 - val_loss: 11.1276 - val_accuracy: 0.8128
# Epoch 19/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.2394 - accuracy: 0.8155 - val_loss: 10.8219 - val_accuracy: 0.8068
# Epoch 20/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.5080 - accuracy: 0.8131 - val_loss: 11.5940 - val_accuracy: 0.8002
# Epoch 21/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.5335 - accuracy: 0.8133 - val_loss: 14.9265 - val_accuracy: 0.7591
# Epoch 22/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.6820 - accuracy: 0.8116 - val_loss: 15.3495 - val_accuracy: 0.7667
# Epoch 23/25
# 60000/60000 [==============================] - 3s 53us/sample - loss: 9.5331 - accuracy: 0.8138 - val_loss: 12.4610 - val_accuracy: 0.7855
# Epoch 24/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.2053 - accuracy: 0.8159 - val_loss: 11.8538 - val_accuracy: 0.8031
# Epoch 25/25
# 60000/60000 [==============================] - 3s 54us/sample - loss: 9.6846 - accuracy: 0.8150 - val_loss: 14.0880 - val_accuracy: 0.7657
